# %% [markdown]
# <h1>Methodologies of Data Science Final Assignment</h1><br>

# %% [markdown]
# <h3>What topic did you choose to apply the Data Science Methodology to ?<h3>

# %% [markdown]
# I chose the credit card topic since I am a student myself in a foreign country and this was an important and helpful step in my education.

# %% [markdown]
# <h3>Next, you will play the role of the client and the data scientist.</h3><br>
#
# <h3>Using the topic that you selected, complete the Business Understanding stage by coming up with a problem that you would like to solve and phrasing it in the form of a question that you will use data to answer.</h3>

# %% [markdown]
# <h3>You are required to:<h3><br>
#
# <ul>
#     <li><h3>Describe the problem, related to the topic you selected.</h3></li>
#     <li><h3>Phrase the problem as a question to be answered using data.</h3></li>
#     </ul>

# %% [markdown]
# <p>I assume the main problem with credit cards is the banks decision on who to grant it or not. Certiain clients will not be feasible for instance students, who don't have the necessary financial backup to be eligible per se.</p><br>
#
# <p><strong>Question:</strong> <i>"Can we automatically determine if a student is eligible for a credit card ?"</i></p>

# %% [markdown]
# <h3>Briefly explain how you would complete each of the following stages for the problem that you described in the Business Understanding stage, so that you are ultimately able to answer the question that you came up with:<h3>
#
# Analytic Approach
#
# Data Requirements
#
# Data Collection
#
# Data Understanding and Preparation
#
# Modeling and Evaluation

# %% [markdown]
# <strong>Analytic Approach:</strong> Since the problem will be answered as a Yes/No, a classification model will be used.
#
# <strong>Data Requirements:</strong> To create the classification model, we will use information regarding the bank clients. This information should include personal data of the clients and should include the ones that defaulted and the one that paid.
#
# <strong>Data Collection:</strong> We'll be using techniques like descriptive statistics, then data evaluation will be implemented in this phase to make sure that we have useful data for our model.
#
# <strong>Data Understanding and Preparation:</strong> Here we will evaluate the different variables of our data in order to better understand it. In the data preparation phase we have to prepare the data in an specific way depending on the model.
#
# <strong>Modeling and Evaluation:</strong> Finally, we create a classification model, evaluate the outcome and perform the corresponding changes until we have a suitable model.

# %% [markdown]
# <i>Made By Arvish<i>
